# %%
from injector import CustomeDataSet
from plot import plot

# %%
dados = CustomeDataSet(r'C:\Users\Breno HM Rodrigues\Desktop\Mestrado\Algortimo\gerdau\dateset_generator', criterio='Data')

# %%
dados[0]
# Out:
# ('A36', 6.35, 2, 20, 0.7813060842693044)

# %%
data = {
    'material': [],
    'espessura_chapa': [],
    'num_parafusos': [],
    'diametro_parafuso': [],
    'FS': []
}
for i in range(len(dados)):
    if 'A572_GR50' == dados[i][0]:
        for chave, valor in zip(data.keys(), dados[i]):
            data[chave].append(valor)
plot(data, ['A36', 'A572_GR50', 'A572_GR55'])

# %%
data = {
    'material': [],
    'espessura_chapa': [],
    'num_parafusos': [],
    'diametro_parafuso': [],
    'FS': []
}
for i in range(len(dados)):
    if 'A36' == dados[i][0]:
        for chave, valor in zip(data.keys(), dados[i]):
            data[chave].append(valor)
plot(data, ['A36', 'A572_GR50', 'A572_GR55'])

# %%
temp = []
for i, dado in enumerate(data['num_parafusos']):
    if dado == 8:
        temp.append([data['espessura_chapa'][i], data['diametro_parafuso'][i], data['FS'][i]])
sorted(temp, key=lambda x: x[-1])
# Out:
# [[19.05, 22, 0.16142687691514554],
#  [22.23, 22, 0.16142687691514554],
#  [15.88, 22, 0.18942200191274125],
#  [15.88, 20, 0.1953265210673261],
#  [19.05, 20, 0.1953265210673261],
#  [22.23, 20, 0.1953265210673261],
#  [12.7, 20, 0.19795011657062428],
#  [12.7, 22, 0.23685207798223087],
#  [9.52, 20, 0.2637950136880302],
#  [9.52, 22, 0.3156370818860789],
#  [7.94, 20, 0.3166204635323586],
#  [7.94, 22, 0.3788440038254825],
#  [6.35, 20, 0.39590023314124856],
#  [6.35, 22, 0.47370415596446175],
#  [4.76, 20, 0.5292561011467215],
#  [4.76, 22, 0.6332676611314382]]

# %%
data = {
    'material': [],
    'espessura_chapa': [],
    'num_parafusos': [],
    'diametro_parafuso': [],
    'FS': []
}
for i in range(len(dados)):
    if 'A572_GR55' == dados[i][0]:
        for chave, valor in zip(data.keys(), dados[i]):
            data[chave].append(valor)
plot(data, ['A36', 'A572_GR50', 'A572_GR55'])

# %%
data = {
    'material': [],
    'espessura_chapa': [],
    'num_parafusos': [],
    'diametro_parafuso': [],
    'FS': []
}
for i in range(len(dados)):
    for chave, valor in zip(data.keys(), dados[i]):
        data[chave].append(valor)
plot(data, ['A36', 'A572_GR50', 'A572_GR55'])
