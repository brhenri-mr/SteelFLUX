# %%
from injector import CustomeDataSet
from plot import plot

# %%
data = {
    'material': [],
    'espessura_chapa': [],
    'num_parafusos': [],
    'diametro_parafuso': [],
    'FS': []
}

# %%
dados = CustomeDataSet(r'C:\Users\Breno HM Rodrigues\Desktop\Mestrado\Algortimo\gerdau\dateset_generator', criterio='Data')
len(dados)
# Out:
# 456

# %%
for i in range(len(dados)):
    for chave, valor in zip(data.keys(), dados[i]):
        data[chave].append(valor)

# %%
len(data['material'])
# Out:
# 456

# %%
plot(data, ['A36', 'A572_GR50', 'A572_GR55'])

# %%
data = {
    'material': [],
    'espessura_chapa': [],
    'num_parafusos': [],
    'diametro_parafuso': [],
    'FS': []
}
dados = CustomeDataSet(r'C:\Users\Breno HM Rodrigues\Desktop\Mestrado\Algortimo\gerdau\dateset_generator', criterio='Data')
for i in range(len(dados)):
    if dados[i][-2] == 22:
        for chave, valor in zip(data.keys(), dados[i]):
            data[chave].append(valor)

# %%
from plot import StratificationAnalyzer
plots = StratificationAnalyzer(data)

# %%
plots.generate_distribution_histograms()

# %%
plots.generate_stacked_bar_chart()
# Out:
# C:\Users\Breno HM Rodrigues\Desktop\Mestrado\Algortimo\gerdau\data_preparete\plot.py:207: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   pivot = self.df.groupby(['FS_categoria', 'material']).size().unstack(fill_value=0)

# %%
plots.generate_stratification_matrix()
# Out:
# C:\Users\Breno HM Rodrigues\Desktop\Mestrado\Algortimo\gerdau\data_preparete\plot.py:66: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   pivot = df_material.groupby(['grupo_parafusos', 'FS_categoria']).size().unstack(fill_value=0)
# C:\Users\Breno HM Rodrigues\Desktop\Mestrado\Algortimo\gerdau\data_preparete\plot.py:66: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   pivot = df_material.groupby(['grupo_parafusos', 'FS_categoria']).size().unstack(fill_value=0)
# ...

# %%
plots.print_stratification_report()
# Out:
# ...
#                 RELATÓRIO DE ESTRATIFICAÇÃO - CONEXÕES METÁLICAS
# ...
#
# 📊 Total de amostras: 456
#
# 📋 Distribuição por Material:
# material
# A36          152
# A572_GR50    152
# A572_GR55    152
#
# 🔩 Distribuição por Número de Parafusos:
# num_parafusos
# 2    144
# 4    144
# 6    120
# 8     48
#
# ⚡ Distribuição por Categoria de FS:
# FS_categoria
# (0.0-0.3)    214
# (0.3-0.6)    186
# (0.6-0.8)     53
# (0.8-1.0)      3
#
# 📈 Estatísticas de FS:
# count    456.000000
# mean       0.354922
# std        0.175366
# min        0.115749
# 25%        0.215236
# 50%        0.320498
# 75%        0.428700
# max        0.917993
#
# 🎯 Número de estratos:
#    - Total possível: 48
#    - Com amostras: 31
#    - Vazios: 17
#
# ⚠️  Estratos com poucas amostras (< 10):
#    - ('A36', '2 parafusos', '(0.0-0.3)'): 4 amostras
#    - ('A36', '2 parafusos', '(0.8-1.0)'): 2 amostras
#    - ('A36', '4 parafusos', '(0.6-0.8)'): 1 amostras
#    - ('A36', '4 parafusos', '(0.8-1.0)'): 0 amostras
# ...

# %%
from extra import StratificationAnalyzerExtra
plot = StratificationAnalyzerExtra(data, fixed_material='A36', fixed_diameter=22)

# %%
plot.generate_3d_stratification_matrix()
# Out:
# C:\Users\Breno HM Rodrigues\Desktop\Mestrado\Algortimo\gerdau\data_preparete\extra.py:221: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   pivot = df_esp.groupby(['num_parafusos', 'FS_categoria']).size().unstack(fill_value=0)
# C:\Users\Breno HM Rodrigues\Desktop\Mestrado\Algortimo\gerdau\data_preparete\extra.py:221: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   pivot = df_esp.groupby(['num_parafusos', 'FS_categoria']).size().unstack(fill_value=0)
# ...
